# %%
import pandas as pd
import sqlalchemy
import pymssql
from datetime import datetime

# %%
eng = sqlalchemy.create_engine('postgresql://pd_software:r2G!XK8rhcK#pt9$q*WV@apc-dw.ckfdwu2jz6ya.us-west-2.redshift.amazonaws.com:5439/be_dw')

# %%
q2 = '''SELECT trunc(date_key),name, stack_temp_avg, count(name) cnt from be_dw.f_yum_pwm_hourly_perf where date_key >='1-Oct-20' group by trunc(date_key),name, stack_temp_avg'''
d2 = pd.read_sql_query(q2,eng)

# %%
q3 = '''SELECT trunc(date_key), name,seg1_asr, count(name) cnt from be_dw.f_yum_pwm_hourly_perf where date_key >='1-Oct-20' group by trunc(date_key), name, seg1_asr'''
d3  =pd.read_sql_query(q3,eng)

# %%
q4 = '''SELECT trunc(date_key), name,vertical_spread_avg, count(name) cnt
from be_dw.f_yum_pwm_hourly_perf where date_key >='1-Oct-20' group by trunc(date_key), name, vertical_spread_avg '''
d4 = pd.read_sql_query(q4, eng)

# %%
q5 = '''SELECT trunc(date_key), name, horizontal_spread_avg , count(name) cnt
from be_dw.f_yum_pwm_hourly_perf where date_key >='1-Oct-20' group by trunc(date_key), name, horizontal_spread_avg '''
d5 = pd.read_sql_query(q5,eng)

# %%
q6 = '''SELECT trunc(date_key), name, cold_column_avg , count(name) cnt
from be_dw.f_yum_pwm_hourly_perf where date_key >='1-Oct-20' group by trunc(date_key), name, cold_column_avg '''
d6 = pd.read_sql_query(q6,eng)

# %%
q7 = '''SELECT trunc(date_key), name,hot_column_avg, count(name) cnt
from be_dw.f_yum_pwm_hourly_perf where date_key >='1-Oct-20' group by trunc(date_key), name, hot_column_avg '''
d7 = pd.read_sql_query(q7,eng)

# %%
q8 = '''SELECT trunc(date_key), name,delta_t_avg, count(name) cnt
from be_dw.f_yum_pwm_hourly_perf where date_key >='1-Oct-20' group by trunc(date_key), name, delta_t_avg'''
d8 = pd.read_sql_query(q8,eng)

# %%
quer1 = '''select name, date_key, STACK_TEMP_AVG  from be_dw.f_yum_pwm_daily_perf where date_key>='1-Oct-20' order by name, Date_key'''
daily1 = pd.read_sql_query(quer1,eng)

# %%
d1 = daily1.set_index('name')

# %%
quer2 = '''select name, date_key, SEG1_ASR 
from be_dw.f_yum_pwm_daily_perf 
where date_key>='1-Oct-20' order by name, Date_key'''
daily2 = pd.read_sql_query(quer2,eng)

# %%
quer3 = '''select name, date_key, vertical_spread_avg 
from be_dw.f_yum_pwm_daily_perf 
where date_key>='1-Oct-20' order by name, Date_key'''
daily3 = pd.read_sql_query(quer3,eng)

# %%
quer4 = '''select name, date_key, horizontal_spread_avg  from be_dw.f_yum_pwm_daily_perf where date_key>='1-Oct-20' order by name, Date_key'''
daily4 = pd.read_sql_query(quer4,eng)

# %%
quer5 = '''select name, date_key, cold_column_avg  from be_dw.f_yum_pwm_daily_perf where date_key>='1-Oct-20' order by name, Date_key'''
daily5 = pd.read_sql_query(quer5,eng)

# %%
quer6 = '''select name, date_key, hot_column_avg  from be_dw.f_yum_pwm_daily_perf where date_key>='1-Oct-20' order by name, Date_key'''
daily6 = pd.read_sql_query(quer6,eng)

# %%
conn = pymssql.connect(host='sc9engcdmdb01', database='be_dw')
query2 = '''select name, date_key, STACK_TEMP_AVG from f_yum_pwm_daily_perf f inner join d_date d on f.d_date = d.id inner join d_pwm_location p on f.d_pwm_location = p.id where date_key>='1-Oct-20' order by name, Date_key'''
df2  = pd.read_sql_query(query2,conn)

# %%
dm2 = df2.set_index('name')

# %%
query3 = '''select name, date_key, seg1_asr  from f_yum_pwm_daily_perf f inner join d_date d on f.d_date = d.id inner join d_pwm_location p on f.d_pwm_location = p.id where date_key>='1-Oct-20' order by name, Date_key'''
df3  = pd.read_sql_query(query3,conn)

# %%
query4 = '''select name, date_key, vertical_spread_avg from f_yum_pwm_daily_perf f inner join d_date d on f.d_date = d.id inner join d_pwm_location p on f.d_pwm_location = p.id where date_key>='1-Oct-20' order by name, Date_key'''
df4  = pd.read_sql_query(query4,conn)

# %%
query5 = '''select name, date_key, horizontal_spread_avg from f_yum_pwm_daily_perf f inner join d_date d on f.d_date = d.id inner join d_pwm_location p on f.d_pwm_location = p.id where date_key>='1-Oct-20' order by name, Date_key'''
df5  = pd.read_sql_query(query5,conn)

# %%
query6 = '''select name, date_key, cold_column_avg from f_yum_pwm_daily_perf f inner join d_date d on f.d_date = d.id inner join d_pwm_location p on f.d_pwm_location = p.id where date_key>='1-Oct-20' order by name, Date_key'''
df6  = pd.read_sql_query(query6,conn)

# %%
query7 = '''select name, date_key, hot_column_avg from f_yum_pwm_daily_perf f inner join d_date d on f.d_date = d.id inner join d_pwm_location p on f.d_pwm_location = p.id where date_key>='1-Oct-20' order by name, Date_key'''
df7  = pd.read_sql_query(query7,conn)

# %%
stack = []
for i in range(len(daily1)):
    if daily1.iloc[i]['name'] == df2.iloc
    if abs(df2.iloc[i]['STACK_TEMP_AVG']- daily1.iloc[i]['stack_temp_avg'])> 0.1:
        stack.append(df2.iloc[i]['name'])
        #stack.append(df2.iloc[i]['date_key'])

# %%
df2.describe()
# Out:
#        STACK_TEMP_AVG
# count    94721.000000
# mean       790.741427
# std         59.689203
# min          0.000000
# 25%        786.658337
# 50%        793.666834
# 75%        803.062386
# max        837.993570

# %%
daily1.describe()
# Out:
#        stack_temp_avg
# count    80817.000000
# mean       790.724070
# std         59.472528
# min          0.000000
# 25%        786.634839
# 50%        793.632294
# 75%        802.997418
# max        837.981039

# %%
dtem = daily1.set_index('name')

# %%
dtem.head()
# Out:
#               date_key  stack_temp_avg
# name
# ADP003.01A  2020-10-01      792.116025
# ADP003.01A  2020-10-02      792.299998
# ADP003.01A  2020-10-03      793.367784
# ADP003.01A  2020-10-04      794.006634
# ADP003.01A  2020-10-05      792.650322

# %%
seg_5 = []
for i in range(len(df3)):
    if abs(df3.iloc[i]['seg1_asr'] - daily2.iloc[i]['seg1_asr']) > 0.5:
        seg_5.append(df3.iloc[i]['name'])

# %%
seg_null = df3['seg1_asr'].isnull().sum()

# %%
seg_nul = df3[df3.isnull().any(axis = 1)]

# %%
vertical_5 = []
ver_null = daily3['vertical_spread_avg'].isnull().sum()
for i in range(len(daily3)):
    if abs(daily3.iloc[i]['vertical_spread_avg'] - df4.iloc[i]['vertical_spread_avg'])>0.5:
        vertical_5.append(daily3.iloc[i]['name'])

# %%
len(vertical)
# Out:
# 2161

# %%
hor_5 = []
hor_null = daily4['horizontal_spread_avg'].isnull().sum()
for i in range(len(df5)):
    if abs(daily4.iloc[i]['horizontal_spread_avg'] - df5.iloc[i]['horizontal_spread_avg'])>0.5:
        hor_5.append(daily4.iloc[i]['name'])

# %%
hor_nul = daily4[daily4.isnull().any(axis = 1)]

# %%
cold_5 = []
cold_null = daily5['cold_column_avg'].isnull().sum()
for i in range(len(df6)):
    if abs(daily5.iloc[i]['cold_column_avg'] - df6.iloc[i]['cold_column_avg'])>0.5:
        cold_5.append(df6.iloc[i]['name'])

# %%
cold_nul = daily5[daily5.isnull().any(axis = 1)]

# %%
hot_5 = []
hot_null = daily6['hot_column_avg'].isnull().sum()
for i in range(len(df7)):
    if abs(daily6.iloc[i]['hot_column_avg'] - df7.iloc[i]['hot_column_avg'])>0.5:
        hot_5.append(df7.iloc[i]['name'])

# %%
len(hot)
# Out:
# 2280

# %%
hot_nul = daily6[daily6.isnull().any(axis = 1)]

# %%
seg_nul.head()
# Out:
#           name   date_key  seg1_asr
# 11  ADP003.01B 2020-10-01       NaN
# 12  ADP003.01B 2020-10-02       NaN
# 13  ADP003.01B 2020-10-03       NaN
# 14  ADP003.01B 2020-10-04       NaN
# 15  ADP003.01B 2020-10-05       NaN

# %%
hor_nul.head()
# Out:
#             name    date_key  horizontal_spread_avg
# 3369  ATC002.A3A  2020-10-04                    NaN
# 3370  ATC002.A3A  2020-10-05                    NaN
# 3371  ATC002.A3A  2020-10-06                    NaN
# 3380  ATC002.A3B  2020-10-04                    NaN
# 3381  ATC002.A3B  2020-10-05                    NaN

# %%
cold_nul.head()
# Out:
#             name    date_key  cold_column_avg
# 3369  ATC002.A3A  2020-10-04              NaN
# 3370  ATC002.A3A  2020-10-05              NaN
# 3371  ATC002.A3A  2020-10-06              NaN
# 3380  ATC002.A3B  2020-10-04              NaN
# 3381  ATC002.A3B  2020-10-05              NaN

# %%
hot_nul.head()
# Out:
#             name    date_key  hot_column_avg
# 3369  ATC002.A3A  2020-10-04             NaN
# 3370  ATC002.A3A  2020-10-05             NaN
# 3371  ATC002.A3A  2020-10-06             NaN
# 3380  ATC002.A3B  2020-10-04             NaN
# 3381  ATC002.A3B  2020-10-05             NaN

# %%
for i in range(19):
    if hot_nul.iloc[i]['name'] not in seg_nul['name']:
        print(hot_nul.iloc[i]['name'])
# Out:
# ATC002.A3A
# ATC002.A3A
# ATC002.A3A
# ATC002.A3B
# ATC002.A3B
# ATC002.A3B
# ATC002.A3C
# ATC002.A3C
# ATC002.A3C
# ATC002.A3D
# ATC002.A3D
# ATC002.A3D
# GEN006.B6D
# GEN006.B6D
# GEN006.B6D
# GEN006.B6D
# GEN006.B6D
# GEN006.B6D
# GEN006.B6D

# %%
seg_nul['name']
# Out:
# 11       ADP003.01B
# 12       ADP003.01B
# 13       ADP003.01B
# 14       ADP003.01B
# 15       ADP003.01B
#             ...
# 80341    WMT045.05A
# 80342    WMT045.05A
# 80343    WMT045.05A
# 80344    WMT045.05A
# 80703    XLX001.03D
# Name: name, Length: 5422, dtype: object

# %%
f = open('RS_DM_Err.txt','w')

# %%
f.write('Stack Difference sites \n')
# Out:
# 24

# %%
for i in stack:
    f.write(i)
    f.write('\n')

# %%
f.write('\n Horizontal_spread_avg differences sites \n')
for i in hor_5:
    f.write(i)
    f.write('\n')

# %%
f.write('\n Vertical_spread_avg differences sites \n')
for i in vertical_5:
    f.write(i)
    f.write('\n')

# %%
f.write('\n Cold_column_avg differences sites \n')
for i in cold_5:
    f.write(i)
    f.write('\n')

# %%
f.write('\n Hot_column_avg differences sites \n')
for i in hot_5:
    f.write(i)
    f.write('\n')

# %%
f.close()

# %%
seg
# Out:
# ['ADP003.01A',
#  'ADP003.01A',
#  'ADP003.01A',
#  'ADP003.01E',
#  'AGT000.01A',
#  'AGT000.03E',
#  'AGT000.03E',
#  'AGT000.03E',
#  'AGT000.05A',
#  'AGT000.05A',
#  'AGT000.05A',
#  'AGT000.05A',
#  'AGT000.05A',
#  'AGT000.05A',
#  'AGT000.05A',
#  'AGT000.05B',
#  'AGT000.05B',
#  'AGT000.05C',
#  'AGT000.05C',
#  'AGT000.05D',
#  'AGT000.05D',
#  'AGT000.05E',
#  'AGT000.05E',
#  'AGT000.05E',
#  'AGT000.05E',
#  'AGT000.05E',
#  'AGT000.05F',
#  'AGT000.05F',
#  'AGT000.05F',
#  'AGT000.06A',
#  'AGT000.06B',
#  'AGT000.06C',
#  'AGT000.06D',
#  'AGT000.06F',
#  'AGT000.07A',
#  'AGT000.07B',
#  'AGT000.07C',
#  'AGT000.07C',
#  'AGT000.07D',
#  'AGT000.07D',
#  'AGT000.07E',
#  'AGT000.07E',
#  'AGT000.08A',
#  'AGT000.08B',
#  'AGT000.08C',
#  'AGT000.08D',
#  'AGT000.08E',
#  'AGT001.01A',
#  'AGT001.01A',
#  'AGT001.02E',
#  'AGT001.03E',
#  'AGT001.04D',
#  'AGT001.05D',
#  'AHM001.01B',
#  'AHM001.01B',
#  'APP011.A1C',
#  'APP011.A1D',
#  'APP011.A2D',
# ...

# %%
temp = open('Seg1_ASR Differences.txt','w')
temp.write('Seg1_ASR Differences \n')
for i in seg:
    temp.write(i+ '\n')
temp.close()

# %%
daily1['name'][0]
# Out:
# 'ADP003.01A'

# %%
daily1['name'][5]
# Out:
# 'ADP003.01A'
